# %%
print("hello world")
# Out:
# hello world

# %%
from google.adk.agents import Agent
from google.adk.runners import Runner
from google.adk.sessions import InMemorySessionService
from google.adk.tools import google_search
from google.genai import types

print("ADK components imported successfully.")
# Out:
# ADK components imported successfully.

# %%
from google.adk.agents import Agent
from google.adk.tools import google_search

# Root Agent Definition
root_agent = Agent(
    name="helpful_assistant",
    model="gemini-2.5-flash-1.1",
    description="A simple agent that can answer general questions.",
    tools=[google_search],
    system_instruction="You are a helpful assistant. Use Google Search for current info or if unsure."
)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# /tmp/ipykernel_48/226277413.py in <cell line: 0>()
#       3
#       4 # Root Agent Definition
# ----> 5 root_agent = Agent(
#       6     name="helpful_assistant",
#       7     model="gemini-2.5-flash-1.1",
#
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py in __init__(self, **data)
#     248         # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     249         __tracebackhide__ = True
# --> 250         validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     251         if self is not validated_self:
#     252             warnings.warn(
#
# ValidationError: 1 validation error for LlmAgent
# system_instruction
# ...

# %%
from kaggle_secrets import UserSecretsClient

# Initialize the secrets client
user_secrets = UserSecretsClient()

# Retrieve your Google API key (make sure it's added in Kaggle → Settings → Secrets)
GOOGLE_API_KEY = user_secrets.get_secret("GOOGLE_API_KEY")

# Optional: Configure environment variable if needed
import os
os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY

# Optional: Disable Vertex AI usage (if using Gemini through genai)
os.environ["GOOGLE_VERTEX_AI"] = "FALSE"

print("✅ Setup complete (Google API Key loaded successfully)")

# Just in case the key is missing
if not GOOGLE_API_KEY:
    print("⚠️ Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' in your Kaggle Secrets.")
